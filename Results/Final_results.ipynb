# %%
import numpy as np
import pandas as pd

# %%
SVC_results = pd.read_csv('SVC-Results.csv')
LogReg_results = pd.read_csv('Logistic-Regression-Results.csv')
RandomForest_results = pd.read_csv('Random-Forest-Results.csv')

# %% [raw]
# SVC best results

# %%
SVC_results.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Unnamed: 0              30 non-null     int64
#  1   Team                    30 non-null     object
#  2   predictions             30 non-null     int64
#  3   prediction probability  30 non-null     float64
#  4   Conf                    30 non-null     object
# dtypes: float64(1), int64(2), object(2)
# memory usage: 1.3+ KB

# %%
SVC_results = SVC_results.sort_values(['Conf','prediction probability'], ascending = False)

# %%
SVC_results.iloc[8:15,2] = 0
SVC_results.iloc[23:29,2] = 0

# %%
SVC_results
# Out:
#     Unnamed: 0                    Team  predictions  prediction probability  \
# 29          14   Golden State Warriors            1                1.000000
# 20           5            Phoenix Suns            1                1.000000
# 16           1               Utah Jazz            1                0.985643
# 21           6        Dallas Mavericks            1                0.890659
# 22           7    Los Angeles Clippers            1                0.868424
# 28          13  Portland Trail Blazers            1                0.715284
# 23           8       Memphis Grizzlies            1                0.676011
# 27          12      Los Angeles Lakers            1                0.646166
# 19           4          Denver Nuggets            0                0.584961
# 25          10  Minnesota Timberwolves            0                0.396653
# 15           0        Sacramento Kings            0                0.035531
# ...

# %% [raw]
# random forest best results

# %%
RandomForest_results.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Unnamed: 0              30 non-null     int64
#  1   Team                    30 non-null     object
#  2   predictions             30 non-null     int64
#  3   prediction probability  30 non-null     float64
#  4   Conf                    30 non-null     object
# dtypes: float64(1), int64(2), object(2)
# memory usage: 1.3+ KB

# %%
RandomForest_results = RandomForest_results.sort_values(['Conf','prediction probability'], ascending = False)

# %%
RandomForest_results.iloc[8:15,2] = 0
RandomForest_results.iloc[23:29,2] = 0

# %%
RandomForest_results
# Out:
#     Unnamed: 0                    Team  predictions  prediction probability  \
# 20           5            Phoenix Suns            1                0.979040
# 16           1               Utah Jazz            1                0.951586
# 29          14   Golden State Warriors            1                0.936667
# 21           6        Dallas Mavericks            1                0.783607
# 22           7    Los Angeles Clippers            1                0.767407
# 28          13  Portland Trail Blazers            1                0.726201
# 23           8       Memphis Grizzlies            1                0.690869
# 27          12      Los Angeles Lakers            1                0.648654
# 19           4          Denver Nuggets            0                0.595147
# 25          10  Minnesota Timberwolves            0                0.464882
# 24           9       San Antonio Spurs            0                0.411515
# ...

# %% [raw]
# logistic regression best results

# %%
LogReg_results.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Unnamed: 0              30 non-null     int64
#  1   Team                    30 non-null     object
#  2   predictions             30 non-null     int64
#  3   prediction probability  30 non-null     float64
#  4   Conf                    30 non-null     object
# dtypes: float64(1), int64(2), object(2)
# memory usage: 1.3+ KB

# %%
LogReg_results = LogReg_results.sort_values(['Conf','prediction probability'], ascending = False)

# %%
LogReg_results.iloc[8:15,2] = 0
LogReg_results.iloc[23:29,2] = 0

# %%
LogReg_results
# Out:
#     Unnamed: 0                    Team  predictions  prediction probability  \
# 29          14   Golden State Warriors            1                0.999944
# 20           5            Phoenix Suns            1                0.999798
# 16           1               Utah Jazz            1                0.984719
# 21           6        Dallas Mavericks            1                0.942490
# 22           7    Los Angeles Clippers            1                0.824967
# 28          13  Portland Trail Blazers            1                0.747283
# 19           4          Denver Nuggets            1                0.729345
# 23           8       Memphis Grizzlies            1                0.697896
# 25          10  Minnesota Timberwolves            0                0.663054
# 27          12      Los Angeles Lakers            0                0.503502
# 15           0        Sacramento Kings            0                0.051116
# ...
